# %%
root_folder = os.path.dirname(os.getcwd())
sys.path.insert(0, root_folder)
from cgc.geometry_correction import GeometryCorrection
import glob

import matplotlib.pyplot as plt
# %matplotlib notebook

from ipywidgets import widgets, interact

# %% [markdown]
# # initialize object

# %%
list_tiff = glob.glob('data/tiff/inhomogeneous*.tif')

o_cgc = GeometryCorrection(list_files=list_tiff)
o_cgc.load_files(notebook=True)
# Out:
# HBox(children=(Label(value='Loading sample', layout=Layout(width='20%')), IntProgress(value=0, max=4), Label(value='Time remaining:', layout=Layout(width='10%')), Label(value=' >> calculating << ')))

# %% [markdown]
# ## Display Images

# %%
list_images = o_cgc.list_data

fig1, (ax1, ax2) = plt.subplots(1, 2)
    
def plot(index):
    
    ax1.clear()
    ax1.imshow(list_images[index])
    
    ax2.clear()
    ax2.plot(list_images[index][0,:])
    
interact(plot,
        index = widgets.IntSlider(value=0,
                                max=len(list_images)-1),
                                continuous_update=False)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# interactive(children=(IntSlider(value=0, description='index', max=3), Output()), _dom_classes=('widget-interact',))
# <function __main__.plot>

# %% [markdown]
# # define parameters

# %%
# center of cylinder
pixel_center = 256

# radius of cylinder
outer_radius = 200
inner_radius= 150

# define the parameters
o_cgc.define_parameters(inner_radius=inner_radius, 
                        outer_radius=outer_radius,
                        pixel_center=pixel_center)

# %%
print(o_cgc.outer_radius)
# Out:
# 200

# %% [markdown]
# # Run correction

# %%
o_cgc.correct(notebook=True)
# Out:
# IntProgress(value=0, description='Progress:', max=4)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-342638970872> in <module>()
# ----> 1 o_cgc.correct(notebook=True)
#
# ~/git/CylindricalGeometryCorrection/cgc/geometry_correction.py in correct(self, notebook)
#     261         self.list_data_corrected = []
#     262         for _index, _file in enumerate(self.list_data):
# --> 263             self.list_data_corrected.append(self._correct_file_index(_index))
#     264
#     265             if notebook:
#
# ~/git/CylindricalGeometryCorrection/cgc/geometry_correction.py in _correct_file_index(self, index)
#     233             # _pixel_intensity = self.calculate_pixel_intensity(slice=_slice)
#     234             for _index_pixel, _pixel in enumerate(np.arange(-self.outer_radius, self.outer_radius+1)):
# --> 235                 _intensity_of_pixel = _slice[_index_pixel]
#     236                 _coeff = self.general_correction(x=_pixel)
#     237                 _corrected_value = (_intensity_of_pixel * _coeff ) / 2.0
#
# IndexError: index 301 is out of bounds for axis 0 with size 301
